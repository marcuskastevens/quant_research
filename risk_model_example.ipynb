# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
F: np.ndarray = np.random.normal(size=(100, 10))
F = (F - np.mean(F, axis=0)) / np.std(F, ddof=1)
pd.DataFrame(F)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.503491  0.399153  1.147646 -0.212023 -0.662411  0.261080  0.755759
# 1  -1.132102 -0.231234 -0.486117 -2.025414  1.524798  0.694932 -0.872195
# 2  -0.428102  0.753874 -0.232596  0.466989 -0.564304  1.155720 -0.418953
# 3  -0.055707  0.451304  2.404979 -2.046256 -1.508466  1.041008 -0.706310
# 4   0.082652  0.193158 -0.448472  0.763838 -0.920745  0.148392 -1.207261
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.972432  0.568964 -0.584827 -1.379980 -0.405905  0.437996 -0.860967
# 96 -0.066247  0.344915  0.190415 -0.387870  0.044629 -0.695279  0.139128
# 97 -1.756360 -0.378991 -1.650960  1.236099 -0.877418  0.087772 -0.768475
# 98 -0.529753 -0.414538 -2.124179  0.243367 -0.776824 -0.751131 -0.021289
# 99 -0.499849 -0.225931 -1.293508 -0.224974 -0.314825 -0.535845  0.860103
#
#            7         8         9
# 0   1.252480  0.005464  2.044455
# ...

# %%
C: np.ndarray = np.dot(np.transpose(F), F)
pd.DataFrame(C)
# Out:
#             0          1          2           3          4           5  \
# 0  105.782775   4.116283  11.707371    7.571512  12.732184  -11.601015
# 1    4.116283  99.916930  -5.417853  -14.599602   1.085718    0.204383
# 2   11.707371  -5.417853  85.093516   10.782589   2.282463    8.824617
# 3    7.571512 -14.599602  10.782589  113.351844  -2.389613  -13.978633
# 4   12.732184   1.085718   2.282463   -2.389613  99.432474  -15.933062
# 5  -11.601015   0.204383   8.824617  -13.978633 -15.933062  110.231936
# 6   -5.992577  12.419779   5.208117   -4.026972   1.965713    3.044548
# 7   -2.677006   0.397780 -17.323660   -8.040806  -8.851356   -5.845871
# 8   14.898707  17.451444  -7.064524   -2.740998  -4.062771    4.792988
# 9    0.009565  10.791116   2.530734   -4.078081  -9.490342   -8.000061
#
#            6          7          8           9
# 0  -5.992577  -2.677006  14.898707    0.009565
# 1  12.419779   0.397780  17.451444   10.791116
# ...

# %%
stock_cov: np.ndarray = np.dot(np.dot(F, C), np.transpose(F))
pd.DataFrame(stock_cov)
# Out:
#             0            1           2            3           4           5   \
# 0   882.625546  -494.491508  -84.410186   531.110714   58.344705  -10.446199
# 1  -494.491508  1163.264453   28.178661   212.705286 -371.376051 -102.655287
# 2   -84.410186    28.178661  538.351092   -59.037736  270.498243 -294.568042
# 3   531.110714   212.705286  -59.037736  1772.630292   -0.334580   52.149262
# 4    58.344705  -371.376051  270.498243    -0.334580  667.632504 -245.921878
# ..         ...          ...         ...          ...         ...         ...
# 95  263.617915   372.117530  274.175642   268.484104  132.255556 -364.189019
# 96  267.966912   -69.372179 -223.816985   124.250188 -113.721153   99.046266
# 97   54.854207  -275.871050  200.170145  -193.987107  617.680986 -158.289235
# 98 -334.787538    84.666583   -4.902960  -555.087298  -49.904986   -6.380778
# 99 -167.039321   146.729861   40.654660  -462.931717 -202.368847  -58.311837
#
# ...

# %%
alpha: np.ndarray = np.random.normal(size=(100, 1))
alpha = (alpha - np.mean(alpha, axis=0)) / np.std(alpha, ddof=1)
alpha.sum(), np.abs(alpha).sum()
# Out:
# (1.4432899320127035e-15, 80.05286952271422)

# %%
weights: np.ndarray = alpha / np.sum(np.abs(alpha))
weights.sum(), np.abs(weights).sum()
# Out:
# (2.42861286636753e-17, 1.0)

# %%
plt.plot(weights * 5)

# %%
implied_expected_returns = np.dot(cov, weights)
# Out:
# array([[ 9.60064129e-03],
#        [ 2.13320360e-02],
#        [-1.08219354e-02],
#        [-6.43518042e-03],
#        [-8.19120268e-03],
#        [-6.51393091e-03],
#        [-5.81543780e-04],
#        [-5.01788820e-03],
#        [ 9.87141624e-03],
#        [-1.35208835e-02],
#        [-3.79247927e-04],
#        [ 8.40645076e-03],
#        [ 7.58805759e-03],
#        [-2.93662729e-02],
#        [-1.71630548e-02],
#        [-4.88337162e-03],
#        [ 9.75910680e-03],
#        [-7.64117139e-03],
#        [-2.17006752e-02],
#        [ 7.55589528e-03],
#        [ 1.50459749e-02],
#        [-8.60251861e-03],
#        [-8.80250861e-03],
#        [-2.32210594e-03],
#        [ 5.30925333e-03],
#        [-7.57411165e-03],
#        [ 1.36123502e-02],
#        [-1.86734807e-03],
#        [-9.27138505e-03],
#        [ 7.24036501e-03],
#        [ 2.89282320e-03],
#        [ 1.66241175e-02],
#        [ 1.07946367e-03],
#        [ 1.54749787e-02],
#        [ 8.24824644e-03],
# ...

# %%
implied_expected_returns: np.ndarray = np.random.normal(size=(100, 1))
implied_expected_returns
# Out:
# array([[ 7.91619302e-01],
#        [-2.20443781e-01],
#        [ 4.23040200e-01],
#        [ 1.42100980e-02],
#        [ 2.46899585e-01],
#        [-2.18971715e+00],
#        [-5.93591195e-01],
#        [-1.32122478e+00],
#        [ 5.33904897e-01],
#        [-1.34051438e+00],
#        [-6.84747340e-02],
#        [-1.04903375e+00],
#        [ 2.10531430e-01],
#        [ 3.41841840e-01],
#        [-3.26158315e-02],
#        [-1.38056178e+00],
#        [ 4.66672319e-01],
#        [-1.09475825e+00],
#        [ 3.57472756e-02],
#        [ 6.83613649e-01],
#        [-7.50628724e-01],
#        [-9.06606669e-02],
#        [ 6.06863061e-01],
#        [ 7.86723928e-02],
#        [ 3.87447934e-01],
#        [ 8.77688233e-01],
#        [ 2.11411176e+00],
#        [-9.28808316e-01],
#        [ 9.38007402e-01],
#        [ 7.94081831e-03],
#        [-1.58662899e+00],
#        [ 4.68742189e-01],
#        [-1.04128066e+00],
#        [-6.39083606e-02],
#        [-6.40376887e-02],
# ...
