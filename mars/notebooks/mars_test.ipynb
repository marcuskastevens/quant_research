# %%
# Builtin dependencies
import sys

# External dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Append ML package to path
sys.path.append(r"C:\Users\marcu\Documents\Quant\Programming\quant_research\mars")

# %%
from models.regression import MARS

# %%
# Generate some synthetic data
np.random.seed(69)
X = np.random.rand(100, 2)
y = 3 * X[:, 0] + np.sin(10 * X[:, 1]) + np.random.randn(100) * 0.1

# Fit Random Forest Regressor model
model = MARS(max_terms=5, max_interaction_term_degree=2)
model = model.fit(X, y)

# Make predictions
y_hat = model.predict(X)

# Print the results
print("Predictions:", y_hat)

plt.plot(y_hat)
plt.plot(y)
plt.show()

plt.plot(y_hat - y)
plt.show()

print(np.mean(np.square(y_hat - y)))
# Out:
# Predictions: [ 1.71905025  1.88526512  2.53499075  0.85118531  2.87953705  3.06264157
#   0.13413792  2.05708132  2.25427904 -0.01014006  1.84189535  1.40278016
#   1.25507402  0.5911341   0.07117014  2.14281071  1.33270196  1.16598019
#   0.26564712  1.76834485  2.21602495 -0.42087083  1.23296646  0.96089674
#   1.39495321  2.03328688  3.38687643  0.5247985   2.73106182  0.4747177
#  -0.26960106  0.42701402  3.12421181  2.33647974  3.38764125  1.11721935
#   0.65779402  2.34687053  2.10252283  0.96089674 -0.14550543  1.12124938
#   1.82341368  0.71818861  1.4076429   2.12216508  1.97041147  1.31594657
#   1.3896921   1.53550472  1.27304249  1.41742592  1.64502398  1.01390138
#   2.54864147  2.13364471  1.01586018  1.85038622  1.49810952  3.34383881
#   2.18262977  3.39586091  0.7634786  -0.10153596  1.81345115  2.13314037
#   0.28551065  2.5668      1.87672754  2.78091511  0.91927202  0.55596107
#   1.281575    2.20213612  1.3770097   2.9434144   1.18265504  0.84624075
#   1.69179571 -0.51715084 -0.73173282  2.51322218  1.4942493   0.24187576
#   2.97264742  1.82896887 -0.08869607  3.7290521   1.96510099  0.58318682
#   1.80613025  2.12803271 -0.77484439  0.96089674  1.90187937  0.73071739
#   2.72305812  2.48073248  1.1305864   1.22901022]
# 0.02008926349271069
